# %%
from surprise import BaselineOnly
from surprise import Dataset
from surprise import Reader
from surprise.model_selection.split import train_test_split
from surprise.model_selection import cross_validate, GridSearchCV
import pandas as pd
import numpy as np
import os, io
from surprise import KNNBasic, KNNWithMeans
from surprise import SVDpp
from surprise import SVD
from surprise import accuracy

# %%
ratings_df  = pd.read_csv('../data/ratings.csv')

# %%
# See how many unique items are there in the data to decide the value of k 

len(set(ratings_df['item_id']))
# Out:
# 10974

# %%
reader = Reader(rating_scale=(1,5))  #invoke reader instance of surprise library
data=Dataset.load_from_df(ratings_df,reader) #load dataset into Surprise datastructure Dataset

# %% [markdown]
# # Holdout method

# %%
# I tried grid search but due to the size of the dataset, it took forever to run it so I tried different k and min_k
# a few times with holdout method.

# %%
trainingSet, testSet = train_test_split(data, test_size=0.2, train_size=None, random_state=None, shuffle=True)

# %%
sim_options = {
    'name': 'pearson', #similarity measure default is MSD
    'user_based': False, #user-based CF
    'min_support':25
}

# %%
#KNN
knn = KNNBasic(sim_options=sim_options,k=10,min_k=5) # number of neighbours = 45
knn.fit(trainingSet) #fit model to the training set
predictions_knn = knn.test(testSet) #predict for test set values
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
accuracy.rmse(predictions_knn, verbose=True)
# Out:
# RMSE: 0.9416
# 0.9415999193823226

# %%
predictions_knn
# Out:
# [Prediction(uid='the_abomination', iid=295110, r_ui=2.0, est=2.5134124151376347, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='wassupdardy', iid=72850, r_ui=4.0, est=2.7418674082241115, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='altas2011', iid=8850, r_ui=2.0, est=2.198298821575094, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='nolosing', iid=72850, r_ui=4.0, est=2.3304839339333876, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198053140237', iid=202970, r_ui=1.0, est=2.647489289430651, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198100410705', iid=258160, r_ui=1.0, est=1.4495943177159543, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='76561198097037228', iid=24240, r_ui=3.0, est=1.5154971642923207, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197967584607', iid=9070, r_ui=2.0, est=1.727266465544664, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Xasion', iid=31260, r_ui=1.0, est=1.0898627660108557, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='popcornman812', iid=236390, r_ui=2.0, est=1.7554701997483553, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='sellingsaucymemes', iid=301120, r_ui=1.0, est=2.087927853682572, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198035632910', iid=49520, r_ui=4.0, est=2.8008239277340907, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='gottabesaints', iid=221640, r_ui=1.0, est=2.171576729150071, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198042017482', iid=219540, r_ui=1.0, est=2.3401961355184016, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='DeEggMeister', iid=261880, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198081963796', iid=91310, r_ui=2.0, est=1.9011665876146178, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198022862450', iid=304930, r_ui=1.0, est=2.9275742304125996, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='gooseisthegreatest', iid=254700, r_ui=2.0, est=2.4381278239588284, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='baismastermindo', iid=104900, r_ui=1.0, est=1.4743635168310232, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ToastNotBread', iid=409710, r_ui=1.0, est=1.564225790860017, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198043458582', iid=300580, r_ui=1.0, est=1.0795265678243817, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='sapperau', iid=50620, r_ui=1.0, est=1.282962770438142, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='NoosphereAndTheZone', iid=51100, r_ui=4.0, est=2.447816690803265, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ZeVexKryor', iid=205930, r_ui=1.0, est=2.195429388695536, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198032914296', iid=24800, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561
details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198042923531', iid=204360, r_ui=3.0, est=1.65955848346302, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198056163371', iid=219830, r_ui=2.0, est=2.4216464070944848, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='mrslime2011_batman', iid=313160, r_ui=4.0, est=2.683400077983515, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198026953406', iid=6920, r_ui=1.0, est=1.4242105925321293, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='traviantrav', iid=400, r_ui=1.0, est=1.2808594755821063, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198057443216', iid=409720, r_ui=1.0, est=2.0365374428804848, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197963977595', iid=280, r_ui=1.0, est=1.3963378164908442, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='theoretical_xp', iid=236830, r_ui=2.0, est=2.2520732664176895, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='thisidisused', iid=270170, r_ui=1.0, est=1.377698573691268, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198081009511', iid=218620, r_ui=4.0, est=3.15335736563903, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='YogPoz', iid=316010, r_ui=2.0, est=1.476781284671557, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ALEXTHENINJA007', iid=220200, r_ui=4.0, est=3.2677406982328066, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198030914302', iid=427520, r_ui=1.0, est=1.6674720066425663, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Terminator_Mitch', iid=550, r_ui=4.0, est=1.692908908867056, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='MysticZemo', iid=17450, r_ui=3.0, est=1.2667217154600061, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Thedarkpotato', iid=312750, r_ui=3.0, est=2.3351233445221595, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198010098493', iid=208090, r_ui=2.0, est=1.6764469196806218, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198045022620', iid=4770, r_ui=1.0, est=1.894732870530759, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='rstrolf', iid=12220, r_ui=4.0, est=1.839431199852439, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198030636321', iid=242920, r_ui=4.0, est=2.7997374802564767, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='silentAggressor', iid=24470, r_ui=1.0, est=1.0905862123989953, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='mcyellowbird', iid=244850, r_ui=1.0, est=1.9067041560365192, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197970137892', iid=271290, r_ui=2.0, est=2.8826856820067683, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197987109775', iid=342200, r_ui=2.0, est=2.7888129443267022, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='toliman', iid=1500, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198058177382', iid=72850, r_ui=4.0, est=2.6412020784575283, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='adi_a12', iid=356500, r_ui=1.0, est=1.0979126936453425, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Outbackalien', iid=102200, r_ui=3.0, est=2.3964769318721038, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='bjbuck', iid=73210, r_ui=3.0, est=1.5415075918611023, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198041881075', iid=261510, r_ui=1.0, est=1.480391720755571, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198031492527', iid=57300, r_ui=3.0, est=2.2158931397798134, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='hoppeduppeanut', iid=8800, r_ui=1.0, est=1.7906191209377698, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='DOGGYKUNG', iid=303830, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='thor2424', iid=295110, r_ui=3.0, est=1.6211608933225912, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ThePratama190', iid=223530, r_ui=1.0, est=2.7675520962713933, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198051686686', iid=620, r_ui=3.0, est=1.721847013925321, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Sharkswift', iid=411181, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='thecommunistbear', iid=15380, r_ui=1.0, est=1.7900744537256934, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='rawrvixen', iid=292420, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198015859040', iid=92800, r_ui=1.0, est=1.267752586789523, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='theytookpsshhh', iid=207610, r_ui=2.0, est=2.0091448697556302, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197983589335', iid=238050, r_ui=1.0, est=1.3143183823240805, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198056024842', iid=200510, r_ui=4.0, est=3.5094076824208007, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='aromph', iid=202090, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='adosattack', iid=238320, r_ui=1.0, est=1.7730683076665348, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='tycoonman', iid=313340, r_ui=1.0, est=1.699271362095724, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198043922525', iid=8980, r_ui=4.0, est=1.9439807407920577, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Smiley_Riley02', iid=238430, r_ui=1.0, est=3.4155244317401223, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198064956459', iid=12770, r_ui=1.0, est=1.238909228272873, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198080907405', iid=238960, r_ui=1.0, est=1.174615148849503, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198026511329', iid=550, r_ui=1.0, est=1.6412487671447462, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198035313379', iid=205060, r_ui=1.0, est=1.1928863104373895, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198060619286', iid=409710, r_ui=1.0, est=1.889418878993533, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197997954295', iid=6800, r_ui=2.0, est=2.4378624226114587, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='xXCammoAmmoXx', iid=243870, r_ui=3.0, est=2.039570183268666, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='DrWho', iid=228200, r_ui=1.0, est=2.659390535973469, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197992178226', iid=7600, r_ui=1.0, est=1.3732825397520583, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Efreak', iid=274620, r_ui=1.0, est=2.1877910258982816, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Dolanito500', iid=333930, r_ui=2.0, est=1.685943995027128, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='pyrodeus', iid=1510, r_ui=1.0, est=1.291979181899847, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='qwazyoxyphi', iid=223530, r_ui=1.0, est=2.0246628940862506, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198078724454', iid=260230, r_ui=1.0, est=1.987088536987928, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198015857297', iid=223530, r_ui=1.0, est=1.7623120539150299, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Bradleyrit', iid=216250, r_ui=2.0, est=2.2087656668874196, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198066742126', iid=373680, r_ui=2.0, est=1.3352806480262138, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Cryptonial', iid=200210, r_ui=2.0, est=2.3019694185448047, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='theultimatedan', iid=40400, r_ui=2.0, est=2.076791341900909, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='baeritto', iid=363330, r_ui=3.0, est=2.1884516912070193, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198037086704', iid=400, r_ui=2.0, est=2.0400564078775583, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='pharonmix', iid=500, r_ui=3.0, est=2.9040825670724746, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198133701524', iid=420, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='lordofmcphee', iid=461750, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198045066239', iid=34830, r_ui=1.0, est=2.549036164205662, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198034664008', iid=98400, r_ui=1.0, est=1.0923158340260128, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='w4v3h4ck', iid=55110, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198051352493', iid=9900, r_ui=4.0, est=2.22351129217358, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198028115830', iid=39640, r_ui=1.0, est=1.2045078786213914, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Terminator_Mitch', iid=32400, r_ui=1.0, est=1.1629297763553448, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='kaseotone', iid=302380, r_ui=2.0, est=2.4388391391815896, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='El_Chappo', iid=302610, r_ui=2.0, est=1.103028994168213, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='BrayDog98', iid=70120, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Zacmoo0007', iid=252490, r_ui=1.0, est=1.3613976399723384, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='RAYNNNISREADY', iid=355840, r_ui=1.0, est=2.193641537069307, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198019622401', iid=233450, r_ui=1.0, est=3.134928700856181, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198049562601', iid=227940, r_ui=2.0, est=1.9866689377188138, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198088560485', iid=203160, r_ui=3.0, est=2.3338170560214886, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='lolsif666', iid=42710, r_ui=1.0, est=2.2090640757617885, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198086608130', iid=113200, r_ui=4.0, est=2.8230893364026404, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='masonplays2', iid=358360, r_ui=1.0, est=1.2137279889321302, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198060406659', iid=208090, r_ui=1.0, est=1.9478445724446594, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198051377210', iid=346900, r_ui=4.0, est=1.7451807561825574, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197971366625', iid=204060, r_ui=1.0, est=1.7078454161786345, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198039196385', iid=355840, r_ui=1.0, est=2.590983640602324, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Ineedmoney4food', iid=303210, r_ui=2.0, est=1.3551688678935305, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198018967342', iid=224600, r_ui=3.0, est=2.4017495882570814, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='vinzolvar', iid=201810, r_ui=3.0, est=2.9571529967454, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='millplaygame', iid=225280, r_ui=2.0, est=1.0959230329021281, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Aurora99', iid=211820, r_ui=4.0, est=2.585457276311846, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Wertizl', iid=397080, r_ui=1.0, est=1.935187586774431, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='hyperFlOyDuS', iid=287700, r_ui=1.0, est=2.8498626012256056, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198008901482', iid=212480, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198074231147', iid=299360, r_ui=1.0, est=2.007454462807896, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198082591936', iid=220, r_ui=1.0, est=1.2808044949020128, details={'actual_k': 10, 'was_impossible': False}),
# ...
#  Prediction(uid='vetal93rus', iid=449440, r_ui=2.0, est=1.8118778500778039, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='wfpdrlogan', iid=38410, r_ui=1.0, est=1.5424783465301108, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197999719746', iid=244090, r_ui=1.0, est=1.1013429513996171, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197963638240', iid=60, r_ui=1.0, est=1.7217846216069503, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='zenonist', iid=219540, r_ui=1.0, est=1.4438525370935795, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='TurtleHipster', iid=417860, r_ui=2.0, est=1.6306668570155063, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198042612057', iid=44320, r_ui=2.0, est=1.6535937817140076, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198107235245', iid=80, r_ui=3.0, est=2.6612469542656627, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='76561198071454865', iid=100, r_ui=1.0, est=1.4677778094978868, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198011244140', iid=32380, r_ui=1.0, est=1.0692655186477342, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='heyitissantooo', iid=296150, r_ui=1.0, est=2.2209439215352496, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='aktavite', iid=475150, r_ui=1.0, est=1.095452517667267, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='judgefudge101', iid=272860, r_ui=1.0, est=1.6086927590175524, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='1232999', iid=232210, r_ui=1.0, est=2.8252787835246935, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197968314652', iid=57650, r_ui=1.0, est=1.1782118880861445, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='thehellerphant', iid=17080, r_ui=1.0, est=1.3434024718863713, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198061579283', iid=238530, r_ui=2.0, est=2.2932147426811964, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='GirBobjack', iid=70, r_ui=1.0, est=1.086454075194332, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='PatrickRD', iid=209870, r_ui=1.0, est=1.8863913551144216, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197977172470', iid=24740, r_ui=1.0, est=1.4191157564993029, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='JambiGaming', iid=50620, r_ui=4.0, est=1.6804053689246417, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='blowjobsfurdayzandgayz', iid=473770, r_ui=1.0, est=1.3354391341220795, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='KasmKat', iid=231740, r_ui=2.0, est=1.5266498067488548, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='lavox', iid=33930, r_ui=4.0, est=2.9411488068582234, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='b-b-b-baka', iid=261180, r_ui=3.0, est=2.094010938739146, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='speedyy', iid=24860, r_ui=1.0, est=1.483904539563259, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='MrLunarFish', iid=219640, r_ui=3.0, est=2.7542594245480343, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='meshed', iid=55110, r_ui=1.0, est=2.095387682238932, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198065663269', iid=326960, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198090450471', iid=293500, r_ui=2.0, est=2.011818126462684, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198061097866', iid=230410, r_ui=1.0, est=1.3426101342121552, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='groggubus', iid=301910, r_ui=1.0, est=1.3892733660588383, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='mda7', iid=1500, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='TwoFifthsRetarded', iid=31120, r_ui=1.0, est=1.1512254422438184, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='sicktoilet', iid=437220, r_ui=3.0, est=2.604881956704163, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198076725117', iid=228260, r_ui=1.0, est=1.6631892011505236, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198016487628', iid=43110, r_ui=1.0, est=2.5932224368112875, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197994100808', iid=221380, r_ui=2.0, est=2.0092594991857267, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198046193884', iid=437220, r_ui=2.0, est=2.888795367256148, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='n-j-s', iid=241930, r_ui=1.0, est=2.6395564865079884, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='rawrvixen', iid=301750, r_ui=2.0, est=2.096895081954929, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='kimmyboy', iid=71340, r_ui=2.0, est=3.111519487771272, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='dvorak33', iid=232210, r_ui=1.0, est=1.3458259814849056, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='wasabiFish', iid=213670, r_ui=1.0, est=1.7150157104644606, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198000508567', iid=377160, r_ui=1.0, est=1.4926587205179231, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Dujidahn', iid=386360, r_ui=2.0, est=2.7075992288704325, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='cytosin3', iid=550, r_ui=2.0, est=1.927240131738507, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198075072893', iid=4000, r_ui=4.0, est=2.2771109292729808, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197974180292', iid=43160, r_ui=1.0, est=1.8135886575085625, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198074027462', iid=218230, r_ui=1.0, est=2.2770961712288877, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198042111289', iid=237110, r_ui=2.0, est=2.924101281230149, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='kitty_47', iid=260710, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198065795972', iid=33910, r_ui=3.0, est=2.9200249614714533, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='channel28', iid=253030, r_ui=2.0, est=1.892595969304813, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198092262100', iid=458320, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='KernzieHD', iid=205790, r_ui=1.0, est=1.3457357933800522, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='AlmightyShippo', iid=32460, r_ui=1.0, est=1.0854994898022123, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='JuanManSnipez', iid=265630, r_ui=1.0, est=2.0333111539009696, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='MeechIsDead', iid=304930, r_ui=4.0, est=1.964900030668089, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Excentricity', iid=219540, r_ui=1.0, est=2.351356410541718, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='barkgamers', iid=400, r_ui=1.0, est=2.6271466407236095, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Glenbluey', iid=31290, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='mistermooth', iid=94200, r_ui=1.0, est=1.22327104572989, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='peter1023199', iid=341870, r_ui=1.0, est=1.902256221396461, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='ExaultGG', iid=341720, r_ui=1.0, est=1.5222585569652494, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='bunyipswamp', iid=223530, r_ui=1.0, est=1.4431660613644455, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198026332576', iid=242860, r_ui=3.0, est=1.9688763604961592, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198115649560', iid=218620, r_ui=4.0, est=2.927623408067524, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197997555288', iid=2200, r_ui=1.0, est=1.9982071423203058, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198068259362', iid=80, r_ui=1.0, est=1.1506620548611255, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198083390406', iid=110800, r_ui=3.0, est=3.171530630377745, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198027156162', iid=40800, r_ui=2.0, est=2.09407579986772, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198024997743', iid=9340, r_ui=1.0, est=1.2298133172734884, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='TunaCanoe', iid=4000, r_ui=4.0, est=2.1633693536032643, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Joebert_', iid=224540, r_ui=1.0, est=2.437627480022698, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='phrostb', iid=388080, r_ui=1.0, est=1.3888401888896915, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='TheLightGamer', iid=11280, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198008026450', iid=12830, r_ui=2.0, est=1.7150100589782284, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198060522166', iid=500, r_ui=1.0, est=1.9114849075471545, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='oklusion', iid=18400, r_ui=1.0, est=1.2991454874862212, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Murderousbinkie', iid=232950, r_ui=1.0, est=1.2322174556551062, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198093336165', iid=317360, r_ui=2.0, est=2.3940138152603287, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='sushisushii', iid=730, r_ui=4.0, est=1.2665967014018995, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='76561198042060306', iid=730, r_ui=4.0, est=2.918946791857297, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='wasabiFish', iid=206190, r_ui=1.0, est=1.368625056444235, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='hismouthlookslikeanoreo', iid=227940, r_ui=1.0, est=2.565878958774608, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ZondaZ', iid=49520, r_ui=3.0, est=2.3445353003803184, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='lhzeldaman', iid=10, r_ui=1.0, est=1.8754565141254589, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='pokkles', iid=202690, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='gar3th', iid=475150, r_ui=1.0, est=1.2793641631880415, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='dankafiinet', iid=205930, r_ui=1.0, est=2.2917309667944235, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561197996262501', iid=9340, r_ui=4.0, est=1.2628434456987403, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198047829440', iid=31290, r_ui=1.0, est=1.1654255587747986, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198067276748', iid=304050, r_ui=1.0, est=1.8217663806829694, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='CyberBlade', iid=298030, r_ui=1.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198064955345', iid=200210, r_ui=1.0, est=1.4843657214372188, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='ii_voltage_ii', iid=402840, r_ui=2.0, est=1.0871484055352387, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198006896421', iid=8980, r_ui=3.0, est=3.3197245953992858, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198053441633', iid=252490, r_ui=2.0, est=2.3670514563750715, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198018293914', iid=33930, r_ui=4.0, est=3.243933148709566, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198064608457', iid=35140, r_ui=4.0, est=3.2481771531862877, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='bryscream', iid=221380, r_ui=4.0, est=1.7533265436952319, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198098871349', iid=314450, r_ui=1.0, est=1.093305558900931, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='rondawg666', iid=358340, r_ui=1.0, est=1.9176051820746371, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='jach5270', iid=47830, r_ui=1.0, est=1.9348229741971223, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='AndrewSiqueira', iid=226320, r_ui=2.0, est=2.1130015258130443, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='Wombatmuff', iid=220440, r_ui=3.0, est=2.444857439881368, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='hashtaglmao', iid=205100, r_ui=2.0, est=1.814178694719788, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198072362918', iid=2430, r_ui=1.0, est=1.6205775299702279, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198109654503', iid=238010, r_ui=1.0, est=1.6856383677669453, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198055084117', iid=10, r_ui=1.0, est=1.716465410731746, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='palelord', iid=211400, r_ui=2.0, est=1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='DogeWithDaSwegAndDew', iid=363970, r_ui=4.0, est=1.8650623563453863, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198071985139', iid=220780, r_ui=2.0, est=1.6685072478650198, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='StillAliveStark', iid=200260, r_ui=3.0, est=2.218721070343159, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198045420316', iid=113420, r_ui=2.0, est=3.3105371638807313, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='thefeelswhennogf', iid=224260, r_ui=1.0, est=1.7528552128046653, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198022316719', iid=91310, r_ui=4.0, est=2.9386434886231085, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='jago751', iid=38410, r_ui=1.0, est=1.1877751418213565, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='MediaPuppet', iid=202750, r_ui=1.0, est=1.4931395577425752, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198044958479', iid=205790, r_ui=1.0, est=1.7688207525622295, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='76561198080335726', iid=105600, r_ui=4.0, est=1.8837661495234361, details={'actual_k': 10, 'was_impossible': False}),
#  ...]

# %% [markdown]
# # Precision at k

# %%
from collections import defaultdict
def precision_recall_at_k(predictions, k, threshold):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

# %%
from surprise.model_selection import KFold

kf = KFold(n_splits=5)
knn = KNNBasic(sim_options=sim_options,k=10,min_k=5)

for trainset, testset in kf.split(data):
    knn.fit(trainset)
    predictions = knn.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=10, threshold=2.5)

    # Precision and recall can then be averaged over all users
    print(sum(prec for prec in precisions.values()) / len(precisions))
    print(sum(rec for rec in recalls.values()) / len(recalls))

# %% [markdown]
# # Recommendation

# %%
ui_df = pd.read_json("../data/australian_users_items_fixed.json")

# %%
ui_df.head()

# %%
user_dict = {}
for i in range(len(ui_df)):
    user_dict[str(ui_df.iloc[i].user_id)] = ui_df.iloc[i].user_id

# %%
game_df = pd.read_json("../data/steam_games_fixed.json")

# %%
game_df.head()

# %%
game_dict = {}
for i in range(len(game_df)):
    game_dict[str(game_df.iloc[i].id)] = game_df.iloc[i].title

# %%
# Retrieve the trainset.
trainset = data.build_full_trainset()

# Build an algorithm, and train it. Follow methodology provided previously
algo = KNNBasic(sim_options=sim_options,k=10,min_k=5)
algo.fit(trainset)

# %%
testset = trainset.build_anti_testset()

# %%
# becuase the size of the dataset is too large, I reduced the size by choosing the first 1097400 rows
# choosing 1097400 is because there are 10974 unique items in rating.csv, I decide to test only 100 users
# 10974 x 100 = 1097400 
# The exact number of users is 103 because the number of unrated items for each user is not exact 10974
testset = testset[:1097400]

# %%
predictions = algo.test(testset)

# %%
predictions

# %%
from collections import defaultdict

def getGameRecommendations(topN=3):
    top_recs = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions: 
        top_recs[uid].append((str(iid)+'.0', est))
     
    for uid, user_ratings in top_recs.items():
        user_ratings.sort(key = lambda x: x[1], reverse = True)
        top_recs[uid] = user_ratings[:topN]
     
    return top_recs

# %%
recommendations = getGameRecommendations(3)

# %%
def getGameName(game_id):
    if game_id not in game_dict:
        return game_id
    g = game_dict[game_id]
    return g

# %%
def getGameRecommendationsForUser(userId, recommendations):
    if userId not in user_dict:
        print("User id is not present")
        return
    u_id = user_dict[userId]
    recommended_games = recommendations[u_id]
    game_list = []
    for game in recommended_games:
        game_list.append((getGameName(game[0]),game[1]))
    return game_list

# %%
getGameRecommendationsForUser('js41637',recommendations)

# %%
# In this case the data of the second game recommended is not in the game dataframe so I show the game id.
getGameRecommendationsForUser('76561197970982479',recommendations)
