# %%
from surprise import BaselineOnly
from surprise import Dataset
from surprise import Reader
from surprise.model_selection.split import train_test_split
from surprise.model_selection import cross_validate, GridSearchCV
import pandas as pd
import numpy as np
import os, io
from surprise import KNNBasic, KNNWithMeans
from surprise import SVDpp
from surprise import SVD
from surprise import accuracy

# %%
ratings_df  = pd.read_csv('../data/ratings.csv')

# %%
reader = Reader(rating_scale=(1,5))  #invoke reader instance of surprise library
data=Dataset.load_from_df(ratings_df,reader) #load dataset into Surprise datastructure Dataset

# %%
# See how many unique items are there in the data to decide what should be the biggest candidate k 

len(set(ratings_df['item_id']))
# Out:
# 10974

# %% [markdown]
# # Grid Search

# %%
param_grid = {'k': [5, 10, 25, 50, 100, 150],
              'sim_options': {'name': ['pearson', 'cosine','pearson_baseline'],
                              'min_support': [1, 5, 10, 25, 50, 75],   #the minimum number of common items needed between users to consider them for similarity. For the item-based approach, this corresponds to the minimum number of common users for two items.
                              'user_based': [False]}
              }

# %%
gs = GridSearchCV(KNNBasic, param_grid, measures=['rmse'], cv=5)

# %%
gs.fit(data)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-47a605721ed8> in <module>
# ----> 1 gs.fit(data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/search.py in fit(self, data)
#      86                                                        cv.split(data))
#      87         )
# ---> 88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
#      90                        verbose=self.joblib_verbose)(delayed_list)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/model_selection/validation.py in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     167     fit_time = time.time() - start_fit
#     168     start_test = time.time()
# --> 169     predictions = algo.test(testset)
#     170     test_time = time.time() - start_test
#     171
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in test(self, testset, verbose)
#     162
#     163         # The ratings are translated back to their original scale.
# --> 164         predictions = [self.predict(uid,
#     165                                     iid,
#     166                                     r_ui_trans,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in <listcomp>(.0)
#     162
#     163         # The ratings are translated back to their original scale.
# --> 164         predictions = [self.predict(uid,
#     165                                     iid,
#     166                                     r_ui_trans,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/algo_base.py in predict(self, uid, iid, r_ui, clip, verbose)
#     104         details = {}
#     105         try:
# --> 106             est = self.estimate(iuid, iiid)
#     107
#     108             # If the details dict was also returned
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/knns.py in estimate(self, u, i)
#     108         x, y = self.switch(u, i)
#     109
# --> 110         neighbors = [(self.sim[x, x2], r) for (x2, r) in self.yr[y]]
#     111         k_neighbors = heapq.nlargest(self.k, neighbors, key=lambda t: t[0])
#     112
#
# ~/opt/anaconda3/lib/python3.8/site-packages/surprise/prediction_algorithms/knns.py in <listcomp>(.0)
#     108         x, y = self.switch(u, i)
#     109
# --> 110         neighbors = [(self.sim[x, x2], r) for (x2, r) in self.yr[y]]
#     111         k_neighbors = heapq.nlargest(self.k, neighbors, key=lambda t: t[0])
#     112
#
# KeyboardInterrupt:

# %%
# best RMSE score
print(gs.best_score['rmse'])

# %%
print(gs.best_params['rmse'])

# %%
knn = gs.best_estimator['rmse']
knn.fit(data.build_full_trainset())

# %% [markdown]
# # Holdout method

# %%
trainingSet, testSet = train_test_split(data, test_size=0.2, train_size=None, random_state=None, shuffle=True)

# %%
sim_options = {
    'name': 'pearson', #similarity measure default is MSD
    'user_based': False #user-based CF
}

# %%
#KNN
knn = KNNBasic(sim_options=sim_options,k=25,min_k=15) #neighbours=3, other parameters set as above
knn.fit(trainingSet) #fit model to the training set
predictions_knn = knn.test(testSet) #predict for test set values
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
accuracy.rmse(predictions_knn, verbose=True)
# Out:
# RMSE: 1.3555
# 1.3554619872924982

# %%
predictions_knn
# Out:
# [Prediction(uid='elgerjp', iid=96100, r_ui=2.0, est=2.040556944631146, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197970147684', iid=252950, r_ui=4.0, est=1.6234746341670279, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='LongLiveAlex', iid=205790, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198082801138', iid=201230, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='InTranze', iid=399790, r_ui=2.0, est=2.081530008756818, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198048334813', iid=113020, r_ui=0.0, est=1.1522665086942405, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Sickosno', iid=263280, r_ui=4.0, est=1.2060579760266028, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198062315054', iid=205790, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='glytche', iid=113200, r_ui=4.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561197961892438', iid=380, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='FubDuck', iid=22600, r_ui=0.0, est=1.3513047020319762, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='MattaPuttasPT', iid=253940, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198031162927', iid=283290, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198091438947', iid=32370, r_ui=3.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198043920464', iid=301520, r_ui=2.0, est=1.5675506118219174, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='kaseotone', iid=4000, r_ui=4.0, est=2.160203857025474, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='agooglemail', iid=283390, r_ui=2.0, est=2.157392365217917, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198140607750', iid=336670, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198039746024', iid=32350, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198030174735', iid=319180, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198021235103', iid=227940, r_ui=2.0, est=2.7012153559340595, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='phrostb', iid=307900, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='nydac98', iid=25890, r_ui=2.0, est=2.0300972502045944, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='HitsugayaL', iid=3700, r_ui=3.0, est=1.0236830428273276, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='utmostnarc', iid=39530, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ToastBasket', iid=238210, r_ui=2.0, est=2.27686030416426, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='DisIsHardCore', iid=238430, r_ui=3.0, est=2.3398900323871503, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198103371005', iid=458300, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='r3koil', iid=30, r_ui=0.0, est=1.2286957163927017, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198054646129', iid=222730, r_ui=2.0, est=2.8030323508936146, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='tomsta', iid=359550, r_ui=4.0, est=2.8022585874578576, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Zombiejebus', iid=46000, r_ui=2.0, est=1.9680269054019865, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198032541298', iid=105600, r_ui=2.0, est=2.4624431762842667, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='76561198087482311', iid=224600, r_ui=2.0, est=2.112304586420026, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198073586132', iid=266210, r_ui=2.0, est=1.2819187128486722, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198047794908', iid=9480, r_ui=4.0, est=2.3750328951078115, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198053000587', iid=337000, r_ui=4.0, est=1.9678397166131025, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='AttonRisk', iid=413852, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198019549975', iid=388340, r_ui=0.0, est=2.589466612352644, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='sttr_7', iid=17410, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='staleath', iid=303790, r_ui=2.0, est=1.8107757430170446, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ichirukii', iid=250400, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ShrekWillLoveYou', iid=4000, r_ui=4.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='Fiesta787', iid=268750, r_ui=3.0, est=2.759602740123217, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='AwesomeDoofus', iid=1520, r_ui=0.0, est=1.2124048157743519, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='RFSwanson', iid=25800, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='remyau', iid=91200, r_ui=2.0, est=1.5586604793178391, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='mashedspudtatoes', iid=110600, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198072587968', iid=273350, r_ui=0.0, est=1.9795915335154004, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='NighTMarE135', iid=50650, r_ui=4.0, est=1.6072670330932697, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Volcarano4thawin', iid=298240, r_ui=2.0, est=1.4414156997892957, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='MIMMATA', iid=222900, r_ui=2.0, est=2.1358901965953496, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198096068574', iid=335820, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='TPIOMEMES', iid=333930, r_ui=0.0, est=2.4938647299400385, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='LewBrew', iid=346010, r_ui=3.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='CheezeMunchy', iid=42120, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='izaac94', iid=230410, r_ui=0.0, est=2.3271113849832545, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198023475537', iid=57690, r_ui=0.0, est=1.6286737349705214, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ProfPoultry', iid=200710, r_ui=0.0, est=2.711683277775879, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ceige', iid=214190, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='scrodobaggins', iid=270550, r_ui=2.0, est=1.6434847599801738, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198063608381', iid=298630, r_ui=4.0, est=2.0782532179541784, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Insidiousbear', iid=20510, r_ui=2.0, est=2.020821770642728, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Terencio', iid=268420, r_ui=2.0, est=2.0294080670517163, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='brotherone', iid=43110, r_ui=0.0, est=1.2048578514855068, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Yerok', iid=219890, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198136097101', iid=223830, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='overcomingnoxa', iid=381210, r_ui=4.0, est=1.40506220537667, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198042544702', iid=550, r_ui=2.0, est=1.9010081443963307, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197979796744', iid=202970, r_ui=0.0, est=1.9696239106137274, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198048506749', iid=55370, r_ui=0.0, est=1.3263719102794271, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Sicklane', iid=38400, r_ui=0.0, est=1.4049108006684672, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Thrasharrl', iid=218620, r_ui=4.0, est=2.1313848787525065, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='DM420', iid=91200, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198093550604', iid=22380, r_ui=3.0, est=3.0566131499506253, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198085008808', iid=493370, r_ui=2.0, est=2.300276207073008, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198019434222', iid=388320, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Ryusey', iid=72850, r_ui=4.0, est=2.543271884564389, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='erase883', iid=63940, r_ui=0.0, est=2.079871953225714, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Mr_1c3', iid=42850, r_ui=2.0, est=1.7584560164411756, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='76561198087930289', iid=248650, r_ui=2.0, est=1.13885765589796, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='9683n', iid=206420, r_ui=2.0, est=2.3446179451094613, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='mrgeneric', iid=6880, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Steamified', iid=296030, r_ui=3.0, est=2.24, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Blakethesex', iid=107410, r_ui=4.0, est=1.6651793145573341, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='beadwa', iid=241720, r_ui=3.0, est=2.346793006684327, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Playerize', iid=449630, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='PurpleGenius', iid=220160, r_ui=2.0, est=1.784054536388223, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='rothynn', iid=219890, r_ui=0.0, est=1.1020375479827846, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198001743414', iid=204100, r_ui=2.0, est=2.5313666679699995, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198057637896', iid=204360, r_ui=4.0, est=1.0460520737252952, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='decnov81', iid=33930, r_ui=3.0, est=1.1199377158763792, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Ryukaiii', iid=438680, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ChaoticRampage', iid=365720, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198092847310', iid=281200, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='GMCamulos', iid=20510, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='dabrwe', iid=238960, r_ui=3.0, est=2.39142547032318, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198054024205', iid=337000, r_ui=3.0, est=2.6680159233748593, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='SirDickingson', iid=202170, r_ui=2.0, est=1.4313576096651077, details={'actual_k': 25, 'was_impossible': False}),
# ...
#  Prediction(uid='LewBrew', iid=40100, r_ui=3.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='jakenugget', iid=337630, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='IsAPervert', iid=235340, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197969339666', iid=17080, r_ui=0.0, est=1.4951160425216925, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='VENTOOR', iid=209080, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198050266990', iid=393360, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='StuntMobile', iid=250260, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='lilypapa', iid=407530, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198038997293', iid=400430, r_ui=3.0, est=1.9946014086696977, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='KuronishiX', iid=311210, r_ui=4.0, est=1.9939508209604346, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198061532474', iid=247080, r_ui=2.0, est=1.9034513318345923, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='iTzAfroGod', iid=205790, r_ui=0.0, est=1.4777274378553573, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197977544920', iid=209830, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198035533544', iid=290080, r_ui=4.0, est=2.62782858794444, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198084771161', iid=550, r_ui=3.0, est=1.693187938038108, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='stinglock', iid=24780, r_ui=0.0, est=1.3768565530265766, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198045875767', iid=243950, r_ui=3.0, est=2.003260588011528, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='FallingPotato', iid=104900, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='TFWUMastab82Sanic', iid=107900, r_ui=3.0, est=1.216753413459786, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='kodell', iid=358230, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='matrixr', iid=220, r_ui=2.0, est=1.3663677769064793, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='sabretoothwalrus', iid=105600, r_ui=4.0, est=2.3915272493164186, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Sirtriangulo', iid=12250, r_ui=0.0, est=1.0021352061379099, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='sasqnick', iid=299260, r_ui=2.0, est=2.1639216903900538, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198083972463', iid=346110, r_ui=4.0, est=2.658126772509205, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197963130430', iid=17410, r_ui=0.0, est=1.7711278283072536, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='chocolate_fudge', iid=233980, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198040575571', iid=43110, r_ui=0.0, est=1.3666761379705001, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='subaru', iid=273110, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198082666592', iid=263540, r_ui=0.0, est=1.0464532490774001, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='mjtothetop', iid=730, r_ui=4.0, est=2.056841522644522, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='exton', iid=409710, r_ui=0.0, est=1.560095701998539, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198012778055', iid=8190, r_ui=0.0, est=1.1639554207746547, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='catmanbuswell', iid=12900, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198014136515', iid=226580, r_ui=4.0, est=1.4411856299133543, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197983367658', iid=362230, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='get_wr3cked', iid=237110, r_ui=3.0, est=2.0594827753818445, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='Karated', iid=208090, r_ui=2.0, est=1.755585501852216, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Jezza453', iid=223530, r_ui=0.0, est=1.9700391914501627, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='aeyo', iid=234140, r_ui=4.0, est=1.493779320762192, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198079106676', iid=209660, r_ui=4.0, est=1.9399349588441517, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='portal_2_3', iid=202990, r_ui=4.0, est=1.4319047327732197, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198077970864', iid=35450, r_ui=2.0, est=2.1058123917194194, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='kirbysmashed', iid=388620, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197972760236', iid=17340, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198083814843', iid=346120, r_ui=2.0, est=1.835241977541149, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198046324554', iid=113420, r_ui=2.0, est=2.5583295551787533, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='TheCubeyRoad', iid=273350, r_ui=3.0, est=2.13695932375199, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='wake-up', iid=95300, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='OneandOnlyTickle', iid=218740, r_ui=0.0, est=1.4210887736361755, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198056887526', iid=338540, r_ui=0.0, est=1.3362756491655565, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='meismacattack', iid=272060, r_ui=0.0, est=1.915105118454545, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='76561198016750146', iid=240, r_ui=3.0, est=2.9321616037154863, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='LuvsGnomes', iid=274190, r_ui=3.0, est=2.555476095111758, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198031212089', iid=40390, r_ui=4.0, est=2.763718899891527, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198059230493', iid=4000, r_ui=4.0, est=1.9144952812896983, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='Brizbrenz', iid=356670, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='TheHeadBitch', iid=209080, r_ui=4.0, est=3.0466317818974282, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='BroomyBroom', iid=23440, r_ui=0.0, est=1, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='Himanimcool', iid=271290, r_ui=0.0, est=1.2219989383750272, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198100736073', iid=39690, r_ui=0.0, est=1.1233918582709315, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198057771322', iid=243870, r_ui=2.0, est=1.7898255954060753, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198004311251', iid=412830, r_ui=2.0, est=1.7619805472718242, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198042243844', iid=238240, r_ui=0.0, est=2.411994758828308, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='downundabruthahood', iid=224760, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198271751334', iid=107410, r_ui=2.0, est=1, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='76561198066958950', iid=9160, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Tobyrox9', iid=281430, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Chezburgar7300', iid=8850, r_ui=2.0, est=1.996798577730662, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='DuftaCore', iid=333930, r_ui=0.0, est=1.6707468329834076, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198012045442', iid=91310, r_ui=4.0, est=3.1550680736219547, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='sir_afrodite', iid=23490, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198018921691', iid=207170, r_ui=2.0, est=1.9871555584927147, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Durkenheimer', iid=8870, r_ui=0.0, est=1.2579757995575145, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='dizioboy', iid=204300, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='NickSack', iid=105600, r_ui=4.0, est=2.532936415272742, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='auzou', iid=241930, r_ui=0.0, est=1.9325161908432764, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197983495958', iid=42680, r_ui=4.0, est=2.6062611225607175, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='mewmeowmeowmew', iid=248570, r_ui=2.0, est=1.5730912504305676, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='mijiperki', iid=224580, r_ui=0.0, est=1.696799292648461, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='goldenglowgaming', iid=730, r_ui=4.0, est=2.161116812662017, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198042552078', iid=8930, r_ui=3.0, est=2.2387931069904603, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Caliwroth', iid=240, r_ui=0.0, est=1.0702285035764862, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='ydok4', iid=394230, r_ui=3.0, est=1.7775162719619202, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198082066343', iid=270550, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='williamfu', iid=281430, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198028367511', iid=57400, r_ui=3.0, est=1.3271396390199517, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Sigg9', iid=221040, r_ui=3.0, est=1.4293518853031772, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198058247995', iid=326960, r_ui=0.0, est=2.46512100775842, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198051256149', iid=91600, r_ui=3.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='inven', iid=313360, r_ui=2.0, est=1.96, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198037387335', iid=4570, r_ui=2.0, est=1.5682380090288954, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Squattson', iid=304930, r_ui=4.0, est=2.132905520708777, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='MoostachedPikachu', iid=204360, r_ui=3.0, est=1.4372419972271226, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198071626569', iid=219680, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='76561198043232952', iid=397080, r_ui=0.0, est=1.0204953797032215, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198067052749', iid=367540, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='Mage2492', iid=238960, r_ui=3.0, est=2.709307312561035, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198079754660', iid=323370, r_ui=0.0, est=1.429257304975274, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='Shadowz123', iid=475150, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='exton', iid=420, r_ui=3.0, est=1.9694727419373141, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='chickenlaksa', iid=100, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='kasmello', iid=232210, r_ui=0.0, est=1, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='dirtywizard', iid=9340, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197961857584', iid=206420, r_ui=4.0, est=1.96973402762954, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='joaodiniz67', iid=35420, r_ui=2.0, est=1.1905714544300368, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198046914151', iid=80, r_ui=0.0, est=1.2205361773895498, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198088259898', iid=352460, r_ui=2.0, est=1.5542853351396957, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561197998727784', iid=9060, r_ui=4.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Lunadora', iid=250320, r_ui=0.0, est=1.4945835822485987, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198043022568', iid=306480, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='TeenoGames', iid=8930, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='DeadCyngus', iid=250900, r_ui=2.0, est=1.5938041735351287, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='azza213', iid=384740, r_ui=2.0, est=1.8515305753485838, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='barren_cookie', iid=221260, r_ui=3.0, est=1.1211108844221227, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Cactus_Chaos', iid=253030, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Napalm_Industry', iid=329380, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='HittingGuide45', iid=281410, r_ui=2.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='causticsoda', iid=12220, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198043660058', iid=65800, r_ui=3.0, est=2.089019253480494, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198050173375', iid=227300, r_ui=3.0, est=1.673959674897388, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198055324551', iid=200710, r_ui=4.0, est=2.1921721255408033, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198077820909', iid=321360, r_ui=3.0, est=2.4228128518266625, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='76561198004054009', iid=8880, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='iamccd', iid=108800, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='snowypadre', iid=9010, r_ui=0.0, est=1, details={'actual_k': 25, 'was_impossible': False}),
#  ...]

# %% [markdown]
# # Recommendation

# %%
ui_df = pd.read_json("../data/australian_users_items_fixed.json")

# %%
ui_df.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982480
# 1            js41637          888  76561198035864384
# 2          evcentric          137  76561198007712560
# 3         Riot-Punch          328  76561197963445856
# 4              doctr          541  76561198002099488
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
user_dict = {}
for i in range(len(ui_df)):
    user_dict[ui_df.iloc[i].user_id] = ui_df.iloc[i].steam_id

# %%
game_df = pd.read_json("../data/steam_games_fixed.json")

# %%
game_df.head()
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3              彼岸领域                        [Action, Adventure, Casual]
# 4               NaN                                                NaN
#
#                   app_name                    title  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 4            Log Challenge                      NaN
#
#                                                  url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4  http://store.steampowered.com/app/773570/Log_C...          NaN
#
#                                                 tags  discount_price  \
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2  [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                        [Action, Adventure, Casual]            0.83
# 4                    [Action, Indie, Casual, Sports]            1.79
#
#                                          reviews_url  \
# 0  http://steamcommunity.com/app/761140/reviews/?...
# 1  http://steamcommunity.com/app/643980/reviews/?...
# 2  http://steamcommunity.com/app/670290/reviews/?...
# 3  http://steamcommunity.com/app/767400/reviews/?...
# 4  http://steamcommunity.com/app/773570/reviews/?...
#
#                                                specs         price  \
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                    [Single-player]          0.99
# 4  [Single-player, Full controller support, HTC V...          2.99
#
#    early_access        id         developer        sentiment metascore
# 0         False  761140.0         Kotoshiro              NaN       NaN
# 1         False  643980.0  Secret Level SRL  Mostly Positive       NaN
# 2         False  670290.0      Poolians.com  Mostly Positive       NaN
# 3         False  767400.0              彼岸领域              NaN       NaN
# 4         False  773570.0               NaN              NaN       NaN

# %%
game_dict = {}
for i in range(len(game_df)):
    game_dict[game_df.iloc[i].id] = game_df.iloc[i].app_name

# %%
# Retrieve the trainset.
trainset = data.build_full_trainset()

# Build an algorithm, and train it. Follow methodology provided previously
algo = KNNBasic(sim_options=sim_options,k=25,min_k=15)
algo.fit(trainset)

# Find missing values and predict
anti_test_set = trainset.build_anti_testset()
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
#predictions = []
#for i in range(len(anti_test_set)):
#    predict = algo.predict(anti_test_set[i][0], anti_test_set[i][1])
#    predictions.append(predict)

# %%
predictions = algo.test(anti_test_set)

# %%
from collections import defaultdict

def getGameRecommendations(topN=3):
    top_recs = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions: 
        top_recs[uid].append((iid, est))
     
    for uid, user_ratings in top_recs.items():
        user_ratings.sort(key = lambda x: x[1], reverse = True)
        top_recs[uid] = user_ratings[:topN]
     
    return top_recs

# %%
recommendations = getGameRecommendations(3)

# %%
def getGameName(game_id):
    if game_id not in game_dict:
        return ""
    m = game_dict[game_id].split('[')
    temp = m[1].split(']')
    return temp[0]

# %%
def getGameRecommendationsForUser(userId, recommendations):
    if userId not in user_dict:
        print("User id is not present")
        return
    u_id = user_dict[userId]
    recommended_games = recommendations[u_id]
    game_list = []
    for game in recommended_games:
        game_list.append((getGameName(game[0]),game[1]))
    return game_list

# %%
getGameRecommendationsForUser('76561197970982479',recommendations)

# %% [markdown]
# # Precision at k

# %%
def precision_recall_at_k(predictions, k=10, threshold=3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls

# %%
kf = KFold(n_splits=5)

for trainset, testset in kf.split(data):
    algo.fit(trainset)
    predictions = algo.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=5, threshold=2.5)

    # Precision and recall can then be averaged over all users
    print(sum(prec for prec in precisions.values()) / len(precisions))
    print(sum(rec for rec in recalls.values()) / len(recalls))
