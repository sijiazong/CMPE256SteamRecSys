# %% [markdown]
# # ProcessGameMetadata
# 1. clean the metadata from steam games json file
# 2. add bundle data into games metadata as column

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Clean steam games metadata

# %%
games_metadata = pd.read_json('./json_data/steam_games_fixed.json')

# %%
games_metadata.shape
# Out:
# (32135, 16)

# %%
games_metadata = games_metadata.dropna(subset=["id", "app_name"])

# %%
games_metadata = games_metadata.drop_duplicates(["id"])

# %%
list(games_metadata.price)
# Out:
# [4.99,
#  'Free To Play',
#  'Free to Play',
#  0.99,
#  2.99,
#  3.99,
#  9.99,
#  18.99,
#  29.99,
#  nan,
#  nan,
#  'Free',
#  10.99,
#  3.99,
#  2.99,
#  1.5899999999999999,
#  14.99,
#  1.99,
#  59.99,
#  4.99,
#  2.99,
#  0.99,
#  0.99,
#  2.99,
#  2.99,
#  4.99,
#  4.99,
#  9.99,
#  9.99,
#  1.99,
#  3.99,
#  nan,
#  nan,
#  0.99,
#  nan,
#  nan,
#  nan,
#  8.99,
#  0.99,
#  6.99,
#  6.99,
#  9.99,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.99,
#  nan,
#  10.99,
#  9.99,
#  9.99,
#  29.99,
#  1.99,
#  nan,
#  0.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  39.99,
#  'Free',
#  4.99,
#  4.99,
#  4.99,
#  19.99,
#  9.99,
#  7.49,
#  14.99,
#  9.99,
#  4.99,
#  9.99,
#  4.99,
#  9.99,
#  9.99,
#  4.99,
#  4.99,
#  4.99,
#  8.99,
#  19.99,
#  19.99,
#  4.99,
#  nan,
#  19.99,
#  4.99,
#  14.99,
#  4.99,
#  4.99,
#  4.99,
#  2.99,
#  2.99,
#  9.99,
#  2.99,
#  4.99,
#  4.99,
#  12.99,
#  19.99,
#  12.99,
#  12.99,
#  9.99,
#  4.99,
#  6.99,
#  nan,
#  nan,
#  9.99,
#  9.99,
#  9.99,
#  6.99,
#  9.99,
#  19.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  5.99,
#  7.99,
#  9.99,
#  9.99,
#  4.99,
#  2.99,
#  19.99,
#  2.99,
#  14.99,
#  9.99,
#  4.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  4.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  nan,
#  9.99,
#  4.99,
#  7.99,
#  4.99,
#  19.99,
#  2.99,
#  2.99,
#  7.99,
#  4.99,
#  4.99,
#  4.99,
#  9.99,
#  19.99,
#  19.99,
#  4.99,
#  9.99,
#  9.99,
#  2.99,
#  2.49,
#  19.99,
#  9.99,
#  19.99,
#  9.99,
#  9.99,
#  9.99,
#  4.99,
#  4.99,
#  9.99,
#  9.99,
#  9.99,
#  19.99,
#  9.99,
#  9.99,
#  4.99,
#  9.99,
#  15.99,
#  'Free',
#  4.99,
#  19.99,
#  14.99,
#  9.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  9.99,
#  19.99,
#  9.99,
#  19.99,
#  9.99,
#  14.99,
#  7.99,
#  9.99,
#  4.99,
#  9.99,
#  5.99,
#  2.99,
#  4.99,
#  9.99,
#  19.99,
#  9.99,
#  nan,
#  4.99,
#  19.99,
#  nan,
#  9.99,
#  1.25,
#  1.25,
#  4.99,
#  9.99,
#  14.99,
#  4.99,
#  19.99,
#  19.99,
#  19.99,
#  29.99,
#  14.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  1.25,
#  6.99,
#  9.99,
#  2.99,
#  4.99,
#  4.99,
#  14.99,
#  'Free',
#  19.99,
#  4.99,
#  4.99,
#  4.99,
#  14.99,
#  14.99,
#  19.99,
#  4.99,
#  9.99,
#  9.99,
#  4.99,
#  9.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  'Free to Play',
#  9.99,
#  19.99,
#  19.99,
#  9.99,
#  5.99,
#  5.99,
#  9.99,
#  5.99,
#  19.99,
#  9.99,
#  12.99,
#  9.99,
#  6.99,
#  nan,
#  9.99,
#  19.99,
#  19.99,
#  19.99,
#  7.99,
#  9.99,
#  6.99,
#  4.99,
#  9.99,
#  9.99,
#  4.99,
#  4.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  nan,
#  19.99,
#  19.99,
#  9.99,
#  4.99,
#  9.99,
#  9.99,
#  4.99,
#  14.99,
#  9.99,
#  9.99,
#  19.99,
#  19.99,
#  2.99,
#  24.99,
#  9.99,
#  19.99,
#  19.99,
#  17.99,
#  9.99,
#  19.99,
#  9.99,
#  3.99,
#  9.99,
#  9.99,
#  9.99,
#  19.99,
#  14.99,
#  19.99,
#  19.99,
#  4.99,
#  9.99,
#  14.99,
#  9.99,
#  4.99,
#  19.99,
#  4.99,
#  4.99,
#  9.99,
#  9.99,
#  9.99,
#  6.99,
#  14.99,
#  9.99,
#  19.99,
#  4.99,
#  1.99,
#  9.99,
#  19.99,
#  19.99,
#  4.99,
#  9.99,
#  14.99,
#  4.99,
#  19.99,
#  14.99,
#  9.99,
#  9.99,
#  'Free',
#  19.99,
#  9.99,
#  19.99,
#  5.99,
#  9.99,
#  9.99,
#  9.99,
#  9.99,
#  1.99,
#  19.99,
#  9.99,
#  9.99,
#  'Free',
#  4.99,
#  9.99,
#  9.99,
#  4.99,
#  4.99,
#  6.99,
#  6.99,
#  6.99,
#  9.99,
#  19.99,
#  nan,
#  4.99,
#  0.99,
#  6.99,
#  9.99,
#  7.49,
#  9.99,
#  19.99,
#  19.99,
#  4.99,
#  4.99,
#  9.99,
#  19.99,
#  4.99,
#  0.99,
#  9.99,
#  19.99,
#  9.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  1.99,
#  9.99,
#  9.99,
#  2.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  6.99,
#  9.99,
#  nan,
#  14.99,
#  nan,
#  4.99,
#  4.99,
#  19.99,
#  4.99,
#  2.99,
#  2.99,
#  61.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  4.99,
#  2.99,
#  2.99,
#  14.99,
#  9.99,
#  4.99,
#  0.99,
#  4.99,
#  4.99,
#  4.99,
#  'Free',
#  4.99,
#  19.99,
#  14.99,
#  4.99,
#  9.99,
#  3.99,
#  9.99,
#  9.99,
#  9.99,
#  0.99,
#  19.99,
#  4.99,
#  29.99,
#  4.99,
#  9.99,
#  9.99,
#  1.99,
#  1.99,
#  1.99,
#  2.99,
#  9.99,
#  19.99,
#  19.99,
#  14.99,
#  8.99,
#  19.99,
#  nan,
#  1.99,
#  5.99,
#  1.99,
#  19.99,
#  2.99,
#  4.99,
#  5.99,
#  4.99,
#  9.99,
#  1.99,
#  4.99,
#  3.99,
#  19.99,
#  19.99,
#  3.99,
#  2.99,
#  2.99,
#  4.99,
#  4.99,
#  9.99,
#  14.99,
#  2.99,
#  14.99,
#  4.99,
#  29.99,
#  4.99,
#  9.99,
#  9.99,
#  2.99,
#  9.99,
#  nan,
#  19.99,
#  4.99,
#  9.99,
#  19.99,
#  4.99,
#  9.99,
#  7.99,
#  14.99,
#  9.99,
#  5.99,
#  19.99,
#  9.99,
#  19.99,
#  4.99,
#  9.99,
#  6.99,
#  4.99,
#  9.99,
#  4.99,
#  14.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  4.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  9.99,
#  9.99,
#  19.99,
#  4.99,
#  4.99,
#  9.99,
#  1.99,
#  4.99,
#  4.99,
#  1.99,
#  3.99,
#  9.99,
#  6.99,
#  12.99,
#  4.99,
#  9.99,
#  39.99,
#  0.99,
#  4.99,
#  4.99,
#  1.99,
#  9.99,
#  4.99,
#  19.99,
#  9.99,
#  14.99,
#  3.49,
#  3.49,
#  3.49,
#  3.49,
#  9.99,
#  9.99,
#  4.99,
#  14.99,
#  19.99,
#  9.99,
#  4.99,
#  2.99,
#  4.99,
#  9.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  4.99,
#  2.99,
#  4.99,
#  2.99,
#  4.99,
#  2.99,
#  2.99,
#  19.99,
#  3.99,
#  19.99,
#  19.99,
#  19.99,
#  19.99,
#  19.99,
#  4.99,
#  14.99,
#  19.99,
#  5.99,
#  5.99,
#  2.99,
#  19.99,
#  nan,
#  19.99,
#  3.99,
#  6.99,
#  3.99,
#  9.99,
#  4.99,
#  19.99,
#  9.99,
#  4.99,
#  9.99,
#  19.99,
#  9.99,
#  2.99,
#  0.99,
#  0.99,
#  2.99,
#  0.99,
#  0.99,
#  'Free to Play',
#  29.99,
#  3.99,
#  2.99,
#  9.99,
#  3.99,
#  3.99,
#  6.99,
#  3.99,
#  9.99,
#  14.99,
#  9.99,
#  3.99,
#  9.99,
#  9.99,
#  19.99,
#  4.99,
#  9.99,
#  19.99,
#  2.99,
#  9.99,
#  2.99,
#  24.99,
#  2.99,
#  4.99,
#  4.99,
#  9.99,
#  19.99,
#  5.99,
#  0.99,
#  1.99,
#  7.99,
#  7.99,
#  14.99,
#  14.99,
#  19.99,
#  'Free to Play',
#  'Free to Play',
#  'Free to Play',
#  9.99,
#  3.99,
#  9.99,
#  'Free',
#  19.99,
#  9.99,
#  4.99,
#  5.99,
#  9.99,
#  9.99,
#  9.99,
#  2.99,
#  9.99,
#  19.99,
#  1.99,
#  1.99,
#  19.99,
#  1.99,
#  1.99,
#  14.99,
#  3.99,
#  6.99,
#  1.99,
#  4.99,
#  4.99,
#  4.99,
#  4.99,
#  2.99,
#  4.99,
#  9.99,
#  7.99,
#  3.99,
#  0.99,
#  4.99,
#  6.99,
#  nan,
#  4.99,
#  8.99,
#  0.99,
#  9.99,
#  1.99,
#  1.99,
#  0.99,
#  0.99,
#  2.99,
#  6.99,
#  4.99,
#  1.99,
#  14.99,
#  6.99,
#  6.99,
#  6.99,
#  3.99,
#  6.99,
#  4.99,
#  4.99,
#  9.99,
#  4.99,
#  9.99,
#  3.99,
#  2.99,
#  3.99,
#  6.99,
#  4.99,
#  'Free to Play',
#  14.99,
#  29.99,
#  7.99,
#  14.99,
#  3.99,
#  9.99,
#  9.99,
#  19.99,
#  9.99,
#  5.99,
#  4.99,
#  9.99,
#  4.99,
#  6.99,
#  9.99,
#  4.99,
#  9.99,
#  19.99,
#  14.99,
#  4.99,
#  6.99,
#  4.99,
#  14.99,
#  18.99,
#  1.99,
#  2.99,
#  4.99,
#  1.99,
#  5.99,
#  3.99,
#  19.99,
#  1.99,
#  14.99,
#  'Free to Play',
#  8.99,
#  9.99,
#  19.99,
#  5.99,
#  4.99,
#  4.99,
#  4.99,
#  9.99,
#  14.99,
#  8.99,
#  1.99,
#  6.99,
#  'Free to Play',
#  nan,
#  2.99,
#  19.99,
#  6.99,
#  2.99,
#  39.99,
#  19.99,
#  11.99,
#  1.99,
#  4.99,
#  2.99,
#  0.99,
#  nan,
#  1.99,
#  6.99,
#  2.99,
#  9.99,
#  1.99,
#  4.99,
#  1.5899999999999999,
#  5.99,
#  1.99,
#  1.99,
#  3.99,
#  nan,
#  19.99,
#  12.99,
#  'Free to Play',
#  4.99,
#  nan,
#  1.99,
#  7.99,
#  9.99,
#  3.99,
#  1.99,
#  2.99,
#  9.99,
#  2.99,
#  0.99,
#  0.99,
#  2.99,
#  0.99,
#  4.99,
#  0.99,
#  nan,
#  9.99,
#  19.99,
#  3.99,
#  nan,
#  nan,
#  5.99,
#  9.99,
#  2.99,
#  2.99,
#  1.99,
#  2.99,
#  4.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  9.99,
#  0.99,
#  0.99,
#  0.99,
#  nan,
#  nan,
#  0.99,
#  7.99,
#  12.99,
#  9.99,
#  4.99,
#  9.99,
#  19.99,
#  'Free to Play',
#  2.99,
#  1.99,
#  19.99,
#  9.99,
#  9.99,
#  9.99,
#  5.99,
#  4.99,
#  9.99,
#  nan,
#  nan,
#  0.99,
#  39.99,
#  1.99,
#  1.99,
#  1.99,
#  nan,
#  9.99,
#  19.99,
#  1.99,
#  11.99,
#  13.99,
#  3.99,
#  'Free to Play',
#  1.99,
#  6.99,
#  9.99,
#  4.99,
#  9.99,
#  19.99,
#  9.99,
#  5.99,
#  12.99,
#  3.99,
#  19.99,
#  4.99,
#  9.99,
#  9.99,
#  19.99,
#  9.99,
#  4.99,
#  19.99,
#  8.99,
#  2.99,
#  9.99,
#  9.99,
#  4.99,
#  1.99,
#  4.99,
#  3.99,
#  3.99,
#  9.99,
#  0.99,
#  4.99,
#  14.99,
#  8.99,
#  1.99,
#  6.99,
#  4.99,
#  9.99,
#  9.99,
#  29.99,
#  9.99,
#  4.99,
#  2.99,
#  9.99,
#  9.99,
#  6.99,
#  9.99,
#  8.99,
#  3.99,
#  9.99,
#  14.99,
#  9.99,
#  12.99,
#  6.99,
#  1.99,
#  'Free Demo',
#  'Free Demo',
#  19.99,
#  6.99,
#  5.99,
#  9.99,
#  3.99,
#  1.99,
#  4.99,
#  14.99,
#  9.99,
#  9.99,
#  4.99,
#  5.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  2.99,
#  nan,
#  19.99,
#  1.99,
#  2.99,
#  4.99,
#  4.99,
#  19.99,
#  4.99,
#  19.99,
#  3.99,
#  8.99,
#  12.99,
#  29.99,
#  9.99,
#  9.99,
#  6.99,
#  5.99,
#  9.99,
#  19.99,
#  3.99,
#  19.99,
#  1.99,
#  14.99,
#  19.99,
#  1.99,
#  1.99,
#  0.99,
#  nan,
#  'Play for Free!',
#  9.99,
#  9.99,
#  14.99,
#  19.99,
#  2.99,
#  'Free to Play',
#  7.99,
#  14.99,
#  4.99,
#  19.99,
#  34.99,
#  'Play for Free!',
#  19.99,
#  1.99,
#  9.99,
#  8.99,
#  'Free to Play',
#  4.99,
#  5.99,
#  1.99,
#  1.99,
#  6.99,
#  3.99,
#  nan,
#  0.99,
#  0.99,
#  0.99,
#  0.99,
#  0.99,
#  nan,
#  39.99,
#  ...]

# %%
# Change price of free and demo games to 0
free_or_demo = games_metadata['price'].astype(str).str.contains("Free|free|Demo|demo")
games_metadata.loc[free_or_demo, 'price'] = 0

# %%
# Coerce price to numeric, this will change non numeric values to 0
games_metadata.loc[:,'price'] = pd.to_numeric(games_metadata.price, errors='coerce')

# %% [markdown]
# ## Bundle data: create item-bundle mapping and add to games metadata

# %%
with open('./json_data/bundle_data_fixed.json') as f:
    df_items = json.load(f)   
    bundle_df = pd.json_normalize(data=df_items, 
                              record_path='items',
                              meta=['bundle_final_price', 'bundle_url', 'bundle_price', 'bundle_name', 'bundle_id', 'bundle_discount'])

# %%
bundle_df.shape
# Out:
# (3500, 11)

# %%
bundle_df.drop_duplicates(subset=["item_id", "bundle_id"], inplace=True)

# %%
# convert item id to numeric, results will be float though item id is integer, coerce includes nan so can only be float) which is corresponding to the item id in games metadata
bundle_df.item_id = pd.to_numeric(bundle_df.item_id, errors='coerce')

# %%
bundle_df.dropna(subset=["item_id"], inplace=True)

# %%
bundle_df.item_id = bundle_df.item_id.astype(int)
bundle_df
# Out:
#                                  genre  item_id discounted_price  \
# 0                Adventure, Indie, RPG   326950            $8.99
# 1                Adventure, Indie, RPG   331490            $2.99
# 2                Adventure, Indie, RPG   331491            $1.99
# 3                Adventure, Indie, RPG   331492            $0.99
# 4             Adventure, Casual, Indie   348540           $12.99
# ...                                ...      ...              ...
# 3520  Action, Adventure, Casual, Indie   467220            $4.99
# 3521  Action, Adventure, Casual, Indie   485090            $1.99
# 3522          Action, Adventure, Indie   385230            $1.99
# 3523          Action, Adventure, Indie   387880            $1.99
# 3524                     Action, Indie   454130            $1.99
#
#                                       item_url  \
# 0     http://store.steampowered.com/app/326950
# 1     http://store.steampowered.com/app/331490
# 2     http://store.steampowered.com/app/331491
# 3     http://store.steampowered.com/app/331492
# 4     http://store.steampowered.com/app/348540
# ...                                        ...
# 3520  http://store.steampowered.com/app/467220
# 3521  http://store.steampowered.com/app/485090
# 3522  http://store.steampowered.com/app/385230
# 3523  http://store.steampowered.com/app/387880
# 3524  http://store.steampowered.com/app/454130
#
#                                item_name bundle_final_price  \
# 0                         Sword of Asumi             $66.46
# 1            Sword of Asumi - Soundtrack             $66.46
# 2         Sword of Asumi - Graphic Novel             $66.46
# 3     Sword of Asumi - Character Creator             $66.46
# 4                   Divine Slice of Life             $66.46
# ...                                  ...                ...
# 3520                           Dyna Bomb              $5.58
# 3521          Dyna Bomb - Soundtrack OST              $5.58
# 3522                           Ninjahtic              $4.77
# 3523               Ninjahtic Mind Tricks              $4.77
# 3524                Nil-Ninjahtic: Ronin              $4.77
#
#                                              bundle_url bundle_price  \
# 0     http://store.steampowered.com/bundle/450/?utm_...       $73.86
# 1     http://store.steampowered.com/bundle/450/?utm_...       $73.86
# 2     http://store.steampowered.com/bundle/450/?utm_...       $73.86
# 3     http://store.steampowered.com/bundle/450/?utm_...       $73.86
# 4     http://store.steampowered.com/bundle/450/?utm_...       $73.86
# ...                                                 ...          ...
# 3520  http://store.steampowered.com/bundle/588/?utm_...        $6.98
# 3521  http://store.steampowered.com/bundle/588/?utm_...        $6.98
# 3522  http://store.steampowered.com/bundle/594/?utm_...        $5.97
# 3523  http://store.steampowered.com/bundle/594/?utm_...        $5.97
# 3524  http://store.steampowered.com/bundle/594/?utm_...        $5.97
#
#                          bundle_name bundle_id bundle_discount
# 0       Dharker Studio 2015 Complete       450             10%
# 1       Dharker Studio 2015 Complete       450             10%
# 2       Dharker Studio 2015 Complete       450             10%
# 3       Dharker Studio 2015 Complete       450             10%
# 4       Dharker Studio 2015 Complete       450             10%
# ...                              ...       ...             ...
# 3520  Dyna Bomb - Game + OST Pack #1       588             20%
# 3521  Dyna Bomb - Game + OST Pack #1       588             20%
# 3522            The Ninjahtic Series       594             20%
# 3523            The Ninjahtic Series       594             20%
# 3524            The Ninjahtic Series       594             20%
#
# [3500 rows x 11 columns]

# %%
bundle_itemid_df = bundle_df[["item_id", "bundle_name"]].groupby('bundle_name')['item_id'].apply(list).reset_index(name='items')

# %%
bundle_itemid_df
# Out:
#                                           bundle_name  \
# 0    "Bye-Bye, Wacky Planet": Shoot and Dance Edition
# 1                                   .EXE - Game + OST
# 2            100% Orange Juice - All Stars Collection
# 3                                     10tons Shooters
# 4                                        10tons Total
# ..                                                ...
# 607                   Zonitron Productions Mixed Pack
# 608                                     Zotrix Bundle
# 609                            fault complete edition
# 610              onechanbara Z2 :Chaos All DLC Bundle
# 611                        tinyBuild Mega 2016 Bundle
#
#                                                  items
# 0                                     [492130, 509410]
# 1                                     [471640, 489990]
# 2    [282800, 327340, 334080, 338360, 376200, 38879...
# 3                                     [262830, 428750]
# 4             [262830, 370550, 394290, 428750, 525450]
# ..                                                 ...
# 607                   [368900, 410590, 431270, 432150]
# 608                                   [343280, 351720]
# 609                   [286260, 344770, 408360, 441270]
# 610  [464510, 464511, 464512, 464513, 464520, 46452...
# 611           [356570, 368730, 403940, 394310, 207140]
#
# [612 rows x 2 columns]

# %%
item_bundle_df = bundle_df[["item_id", "bundle_name"]].groupby('item_id')['bundle_name'].apply(list).reset_index(name='bundles')

# %%
item_bundle_df
# Out:
#       item_id                                            bundles
# 0          20  [Half-Life Complete, Valve Complete Pack, Half...
# 1          30  [Valve Complete Pack, Counter-Strike 1 Anthology]
# 2          40  [Valve Complete Pack, Counter-Strike 1 Anthology]
# 3          50  [Half-Life Complete, Valve Complete Pack, Half...
# 4          60  [Valve Complete Pack, Counter-Strike 1 Anthology]
# ...       ...                                                ...
# 2782   528389          [Naruto Shippuden Uncut Season 4, Vol. 4]
# 2783   528390          [Naruto Shippuden Uncut Season 4, Vol. 4]
# 2784   528391          [Naruto Shippuden Uncut Season 4, Vol. 4]
# 2785   528392          [Naruto Shippuden Uncut Season 4, Vol. 4]
# 2786   528490       [Halcyon 6: Starbase Commander + Soundtrack]
#
# [2787 rows x 2 columns]

# %% [markdown]
# ## Merge bundle info into metadata

# %%
games_metadata = games_metadata.merge(item_bundle_df, how='left', left_on='id', right_on='item_id')

# %%
games_metadata
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32126   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32127            Sacada                          [Casual, Indie, Strategy]
# 32128      Laush Studio                        [Indie, Racing, Simulation]
# 32129          SIXNAILS                                    [Casual, Indie]
# 32130               NaN                                                NaN
#
#                        app_name                     title  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty
# 1                     Ironbound                 Ironbound
# 2       Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                       弹炸人2222                   弹炸人2222
# 4                 Log Challenge                       NaN
# ...                         ...                       ...
# 32126            Colony On Mars            Colony On Mars
# 32127  LOGistICAL: South Africa  LOGistICAL: South Africa
# 32128             Russian Roads             Russian Roads
# 32129       EXIT 2 - Directions       EXIT 2 - Directions
# 32130               Maze Run VR                       NaN
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/773570/Log_C...          NaN
# ...                                                  ...          ...
# 32126  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 32127  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 32128  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 32129  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 32130  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                     tags  discount_price  \
# 0          [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1      [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 2      [Free to Play, Simulation, Sports, Casual, Ind...             NaN
# 3                            [Action, Adventure, Casual]            0.83
# 4                        [Action, Indie, Casual, Sports]            1.79
# ...                                                  ...             ...
# 32126              [Strategy, Indie, Casual, Simulation]            1.49
# 32127                          [Strategy, Indie, Casual]            4.24
# 32128                        [Indie, Simulation, Racing]            1.39
# 32129  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32130  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/773570/reviews/?...
# ...                                                  ...
# 32126  http://steamcommunity.com/app/773640/reviews/?...
# 32127  http://steamcommunity.com/app/733530/reviews/?...
# 32128  http://steamcommunity.com/app/610660/reviews/?...
# 32129  http://steamcommunity.com/app/658870/reviews/?...
# 32130  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs  price  early_access  \
# 0                                        [Single-player]   4.99         False
# 1      [Single-player, Multi-player, Online Multi-Pla...   0.00         False
# 2      [Single-player, Multi-player, Online Multi-Pla...   0.00         False
# 3                                        [Single-player]   0.99         False
# 4      [Single-player, Full controller support, HTC V...   2.99         False
# ...                                                  ...    ...           ...
# 32126                [Single-player, Steam Achievements]   1.99         False
# 32127  [Single-player, Steam Achievements, Steam Clou...   4.99         False
# 32128  [Single-player, Steam Achievements, Steam Trad...   1.99         False
# 32129   [Single-player, Steam Achievements, Steam Cloud]   4.99         False
# 32130  [Single-player, Stats, Steam Leaderboards, HTC...   4.99          True
#
#              id                 developer        sentiment metascore  item_id  \
# 0      761140.0                 Kotoshiro              NaN       NaN      NaN
# 1      643980.0          Secret Level SRL  Mostly Positive       NaN      NaN
# 2      670290.0              Poolians.com  Mostly Positive       NaN      NaN
# 3      767400.0                      彼岸领域              NaN       NaN      NaN
# 4      773570.0                       NaN              NaN       NaN      NaN
# ...         ...                       ...              ...       ...      ...
# 32126  773640.0        Nikita "Ghost_RUS"              NaN       NaN      NaN
# 32127  733530.0                    Sacada              NaN       NaN      NaN
# 32128  610660.0  Laush Dmitriy Sergeevich              NaN       NaN      NaN
# 32129  658870.0             xropi,stev3ns   1 user reviews       NaN      NaN
# 32130  681550.0                       NaN         Positive       NaN      NaN
#
#       bundles
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 32126     NaN
# 32127     NaN
# 32128     NaN
# 32129     NaN
# 32130     NaN
#
# [32131 rows x 18 columns]

# %%
games_metadata.to_csv("games_metadata.csv", index=False)

# %% [markdown]
# ### Create a full list of games id to name pair for games in both user-items and games metadata
