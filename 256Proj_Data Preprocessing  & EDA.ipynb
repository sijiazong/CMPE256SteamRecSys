# %%
import pandas as pd
import numpy as np
import json

# %%
file_path = './json_data/'
file_names = ['australian_user_reviews', 'australian_users_items', 'bundle_data', 'steam_games']

# %% [markdown]
# ### Fix json file

# %%
def eval_and_redump(text):
    file = open(file_path+text+'.json','r')
    write = open(file_path+text+'_fixed.json','w')
    array = []
    for line in file:
        line_dict = eval(line)
        array.append(line_dict)
    json.dump(array,write)
    return None

# %%
# for name in file_names:
#     eval_and_redump(name)

# %%
df_dict = {}
for name in file_names:
    df_dict[name] = pd.read_json(file_path+name+'_fixed.json')
#     df_dict[name].to_csv(file_path+name+'.csv', index = False)

# %%
df_dict['australian_user_reviews']
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
df_dict['australian_users_items']
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982480
# 1                      js41637          888  76561198035864384
# 2                    evcentric          137  76561198007712560
# 3                   Riot-Punch          328  76561197963445856
# 4                        doctr          541  76561198002099488
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066624
# 88306        76561198326700687          177  76561198326700688
# 88307  XxLaughingJackClown77xX            0  76561198328759264
# 88308        76561198329548331            7  76561198329548336
# 88309        edward_tremethick            0  76561198331598576
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# ...

# %%
df_dict['bundle_data']
# Out:
#     bundle_final_price                                         bundle_url  \
# 0               $66.46  http://store.steampowered.com/bundle/450/?utm_...
# 1               $20.15  http://store.steampowered.com/bundle/1473/?utm...
# 2               $20.15  http://store.steampowered.com/bundle/1474/?utm...
# 3               $15.17  http://store.steampowered.com/bundle/1437/?utm...
# 4               $20.15  http://store.steampowered.com/bundle/1466/?utm...
# ..                 ...                                                ...
# 610              $2.66  http://store.steampowered.com/bundle/582/?utm_...
# 611             $16.18  http://store.steampowered.com/bundle/584/?utm_...
# 612             $43.30  http://store.steampowered.com/bundle/586/?utm_...
# 613              $5.58  http://store.steampowered.com/bundle/588/?utm_...
# 614              $4.77  http://store.steampowered.com/bundle/594/?utm_...
#
#     bundle_price                              bundle_name  bundle_id  \
# ...

# %%
df_dict['steam_games']
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...
